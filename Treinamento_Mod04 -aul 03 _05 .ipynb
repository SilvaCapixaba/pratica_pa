# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np
#'random' gera numeros aleatórios / seed() determina para gerar exatamente a mesma sequências de numeros
#'randit' permite gerar numeros inteiros aleátorios, é uma funcinalidade do modulo ramdon
#'size' retorna o tamanho de um DataFrame ou uma serie /('serie' retorna o numero de linhas) - ('DataFrame' ele retorna o produto do numero de linhas e coluna
np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1)  Calculo do percentual de acerto dos alunos por assunto
#'df_mat' Neste DataFrame eu tenho a quantidade de acertos
pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  8
pc_qui = df_qui /  8

# %%
# 2) Calcule o total de acertos de cada aluno.
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Calcule o porcentual geral de cada aluno.
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?
total_gt_45 = total[total['Qt_acertos'] > 45]
total_gt_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
#Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo DataFrame com os alunos desqualificados por este critério.
#estou dizendo que tiver nota == 0 , estou colocando na variavel DataFrame df_eliminados
df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
vacAcre = pd.read_csv(
    'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-b011e4f2-6e3d-4820-b79f-f8d0993fbb73.c000.csv',
    sep=';')
vacAcre
# Out:
#                                       document_id  \
# 0       c0cb9102-6f8b-4c5b-b465-6e6260d099e3-i0b0
# 1       27d36df4-8765-450b-8137-ad009972631c-i0b0
# 2       7ba7bdcd-8553-4d14-a289-cdcb1039245c-i0b0
# 3       27d85a4a-8bd4-4385-9f0a-132eed383d79-i0b0
# 4       29d92551-6fa9-4b2a-a68e-1865a0683843-i0b0
# ...                                           ...
# 386034  f5774216-c638-4d44-9fe5-406b644bcfa6-i0b0
# 386035  f5a3e962-3526-4daa-ba90-fbeaced43cae-i0b0
# 386036  f5b6713a-b6ff-4eda-9d54-ca41af39f41f-i0b0
# 386037  f5c89b1b-6d08-42ba-a880-f94eafdb5305-i0b0
# 386038  f5dc4de9-0734-4245-b271-0962dcf09a77-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       25907ef4e2ebfd876dd79b3613d2d0cf354f638f419154...              41
# 1       0b69fdeb035779890343198429c32af6fe030bb73a9448...              14
# 2       13689b50030733e6f965c69412680c8b321acbdb683434...              22
# ...

# %%
vacAcre.head(2)
# Out:
#                                  document_id  \
# 0  c0cb9102-6f8b-4c5b-b465-6e6260d099e3-i0b0
# 1  27d36df4-8765-450b-8137-ad009972631c-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  25907ef4e2ebfd876dd79b3613d2d0cf354f638f419154...              41
# 1  0b69fdeb035779890343198429c32af6fe030bb73a9448...              14
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1980-10-04                          M                        1
# 1              2007-10-01                          F                        3
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                 BRANCA                           120040.0
# 1                  PARDA                           120001.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                    ACRELANDIA  ...
#
# ...

# %%
#shape retorna o numero de linhas
vacAcre.shape[0]
# Out:
# 386039

# %%
# 2) Quantidade de pacientes vacinados
vacAcre['paciente_id'].nunique()
# Out:
# 315739

# %%
# 3) Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método .unique()
#pega o valor unico onde aparece uma vez
#loc permite que eu selecione dados com baseem rotulos de indice(conteudo da linha e coluna)
primeira_dose = vacAcre['vacina_descricao_dose'].unique()[0] #pega o valor unico da coluna, começando com a primeira posição [0]
vacAcre['paciente_id'].loc[vacAcre['vacina_descricao_dose'] == primeira_dose].nunique() #pega cada cliente(.loc)
# Out:
# 72247

# %%
# 3) solução alternativa de codgo com mesmo efeito que o anterior
primeira_dose = vacAcre['vacina_descricao_dose'].unique()[0]
df_primeira_dose = vacAcre[vacAcre['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 72247

# %%
# 4) Paciente com idade menor que 18
df_menor = vacAcre[vacAcre["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 67667

# %%
# 5) Nome não se encontra na base de dados
#vacAcre['estabelecimento_razaosocial'].nunique()

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) cópia do DataFrame original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
df_menor = vacAcre[vacAcre["paciente_idade"]<18].copy()
df_menor
# Out:
#                                       document_id  \
# 1       27d36df4-8765-450b-8137-ad009972631c-i0b0
# 5       27e31a40-da4b-404a-9bf8-7c0bd60a229d-i0b0
# 17      28db64ca-c241-4696-9354-03c560e0bb9f-i0b0
# 24      2662e720-2197-45c4-a041-1d949ae19f96-i0b0
# 26      a721fe63-0a33-4f13-b28a-ae513429610d-i0b0
# ...                                           ...
# 386019  f3bbc6a0-48e9-43ba-8e20-d1d2c49d1417-i0b0
# 386023  f41303f8-11a6-4192-ae50-c43e23873690-i0b0
# 386024  f425c10c-0aaf-4adb-bb11-31f5ae811130-i0b0
# 386025  f42c774d-59c0-45de-840d-881e2d1faa86-i0b0
# 386034  f5774216-c638-4d44-9fe5-406b644bcfa6-i0b0
#
#                                               paciente_id  paciente_idade  \
# 1       0b69fdeb035779890343198429c32af6fe030bb73a9448...              14
# 5       81e4fa991135c8a6123ff3b4119afa5e98c61f82128432...              10
# 17      d9855607e17f552d46135c94ca1583309b2bf34a7dbe48...              16
# ...

# %%
# 2) tenho todas as colunas existentes na base de dados
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3) Nesse DataFrame tenho contagem do campo nome das categorias de pessoas, classes que receberam as vacinas 'vacina_categoria_nome'
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      47001
# Povos Indígenas                                    4555
# Outros                                             3755
# Povos e Comunidades Tradicionais                    815
# Trabalhadores de Saúde                              249
# Comorbidades                                         56
# População Privada de Liberdade                       53
# Gestantes                                            42
# Pessoas com Deficiência                              11
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Trabalhadores da Educação                             1
# Name: count, dtype: int64

# %%
# 4) Não existe a existencias destes dados 
#lista_variaveis = ['estabelecimento_valor',
       #'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       #'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       #'estabelecimento_uf']
#df_menor_lista = df_menor.loc[:,lista_variaveis]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 6
#       1 # 4)
#       2 lista_variaveis = ['estabelecimento_valor',
#       3        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#       4        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#       5        'estabelecimento_uf']
# ----> 6 df_menor_lista = df_menor.loc[:,lista_variaveis]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# ...

# %%
# 5)
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista.shape
